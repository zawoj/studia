# %%
import Plots

Plots.quiver([1, 2,3], [ 1, 2, 3], quiver=([2], [3]))

# %%
x = range(0, 10, length=100)
y = sin.(x)
y_noisy = @. sin(x) + 0.1 * randn()

Plots.plot(x, y, label="sin(x)")
Plots.plot!(x, y_noisy, seriestype=:scatter, label="data")
